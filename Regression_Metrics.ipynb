# %%
import pandas as pd

# %%
df=pd.read_csv("placement (2).csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
# seperate input and output variables

x=df[["cgpa"]]
y=df[["package"]]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
# train test split

from sklearn.model_selection  import train_test_split
x_tran,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# model training
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
# prediction

y_predicted=model.predict(x_test)

# %%
# r2 score
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_predicted)
r2
# Out:
# 0.7755399367938213

# %%
# MAE --> Mean Abs. Error
# MSE --> Mean Squared Error

from sklearn.metrics import mean_absolute_error,mean_squared_error

mse=mean_squared_error(y_test,y_predicted)
mae=mean_absolute_error(y_test,y_predicted)

# %%
mse
# Out:
# 0.08327062913960064

# %%
mae
# Out:
# 0.22971506127535252

# %%
# Adjusted R2 Score
p=1 # no of input variable
n=40 # no of rows in test data set --> x_test.shape

adj_r2=1-(1-r2*r2)*(n-1)/(n-p-1)
adj_r2
# Out:
# 0.5909743565506422

# %%
import numpy as np

new_df=df.copy()
new_df["random_feature"]=np.random.random(200)

# %%
new_df
# Out:
#      cgpa  package  random_feature
# 0    6.89     3.26        0.415410
# 1    5.12     1.98        0.171700
# 2    7.82     3.25        0.936515
# 3    7.42     3.67        0.257086
# 4    6.94     3.57        0.701354
# ..    ...      ...             ...
# 195  6.93     2.46        0.977469
# 196  5.89     2.57        0.992777
# 197  7.21     3.24        0.750394
# 198  7.63     3.96        0.444507
# 199  6.22     2.33        0.712482
#
# [200 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(x=new_df["random_feature"],y=new_df["package"])
plt.xlabel("random_feature")
plt.ylabel("package")
# Out:
# Text(0, 0.5, 'package')

# %%
# seperate input and output variables

x=new_df[["cgpa","random_feature"]]
y=new_df[["package"]]

# %%
# train test split

from sklearn.model_selection  import train_test_split
x_tran,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# model training
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
# r2 score
from sklearn.metrics import r2_score

y_predicted=model.predict(x_test)
r2=r2_score(y_test,y_predicted)

# %%
r2 # r2 score increased even if i added a meaningless/unuseful feature
# Out:
# 0.7770522833677355

# %%
# Adjusted R2 Score
p=2 # no of input variable
n=40 # no of rows in test data set --> x_test.shape

adj_r2=1-(1-r2*r2)*(n-1)/(n-p-1)
adj_r2 # adjusted r2 score decreased as it penalized the unnecesary feature.
# Out:
# 0.5823945889836066

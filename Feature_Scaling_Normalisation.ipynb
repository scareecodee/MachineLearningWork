# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
sns.lineplot(x=df["alcohol"],y=df["quality"])
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>

# %%
sns.lineplot(x=df['free sulfur dioxide'],y=df["quality"])
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='quality'>

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# seperate input and output variables
x=df[['free sulfur dioxide','alcohol',"fixed acidity","volatile acidity","citric acid"]]
y=df[['quality']]

# %%
x
# Out:
#       free sulfur dioxide  alcohol  fixed acidity  volatile acidity  \
# 0                    11.0      9.4            7.4             0.700
# 1                    25.0      9.8            7.8             0.880
# 2                    15.0      9.8            7.8             0.760
# 3                    17.0      9.8           11.2             0.280
# 4                    11.0      9.4            7.4             0.700
# ...                   ...      ...            ...               ...
# 1138                 29.0     11.0            6.3             0.510
# 1139                 28.0      9.5            6.8             0.620
# 1140                 32.0     10.5            6.2             0.600
# 1141                 39.0     11.2            5.9             0.550
# 1142                 32.0     10.2            5.9             0.645
#
#       citric acid
# 0            0.00
# 1            0.00
# 2            0.04
# 3            0.56
# 4            0.00
# ...           ...
# 1138         0.13
# 1139         0.08
# 1140         0.08
# 1141         0.10
# 1142         0.12
#
# [1143 rows x 5 columns]

# %%
y
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1138        6
# 1139        6
# 1140        5
# 1141        6
# 1142        5
#
# [1143 rows x 1 columns]

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.9)

# %%
x_train
# Out:
#       free sulfur dioxide  alcohol  fixed acidity  volatile acidity  \
# 31                    9.0     10.3            8.1              0.66
# 227                  21.0     11.5            9.8              0.66
# 303                  21.0      9.2            7.8              0.55
# 318                  18.0     10.0            6.8              0.56
# 492                  24.0      9.4            9.0              0.47
# ...                   ...      ...            ...               ...
# 9                    15.0      9.2            6.7              0.58
# 373                   6.0      9.4            9.9              0.63
# 666                  11.0     12.1            8.3              0.30
# 497                  26.0     10.1           10.6              1.02
# 1036                 27.0      9.0            7.6              0.49
#
#       citric acid
# 31           0.22
# 227          0.39
# 303          0.35
# 318          0.03
# 492          0.31
# ...           ...
# 9            0.08
# 373          0.24
# 666          0.49
# 497          0.43
# 1036         0.33
#
# [1028 rows x 5 columns]

# %%
x_test
# Out:
#       free sulfur dioxide  alcohol  fixed acidity  volatile acidity  \
# 927                  24.0      9.8            7.5              0.61
# 874                   7.0      9.4            7.8              0.55
# 532                  12.0      9.0            8.2              0.34
# 987                   5.0     11.0            8.0              0.64
# 847                  23.0      9.5            7.9              0.58
# ...                   ...      ...            ...               ...
# 211                  17.0      9.5           13.3              0.34
# 727                   5.0     10.6           10.1              0.37
# 447                   5.0      9.5           10.4              0.28
# 370                  38.0      9.4            9.3              0.40
# 1016                  6.0     11.2            7.6              0.41
#
#       citric acid
# 927          0.26
# 874          0.00
# 532          0.38
# 987          0.22
# 847          0.23
# ...           ...
# 211          0.52
# 727          0.34
# 447          0.54
# 370          0.49
# 1016         0.33
#
# [115 rows x 5 columns]

# %%
y_train
# Out:
#       quality
# 31          5
# 227         7
# 303         5
# 318         6
# 492         5
# ...       ...
# 9           5
# 373         5
# 666         7
# 497         6
# 1036        5
#
# [1028 rows x 1 columns]

# %%
y_test
# Out:
#       quality
# 927         5
# 874         6
# 532         6
# 987         5
# 847         6
# ...       ...
# 211         6
# 727         7
# 447         5
# 370         5
# 1016        5
#
# [115 rows x 1 columns]

# %%
# scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[0.11940299, 0.29230769, 0.30973451, 0.36986301, 0.22      ],
#        [0.29850746, 0.47692308, 0.46017699, 0.36986301, 0.39      ],
#        [0.29850746, 0.12307692, 0.28318584, 0.29452055, 0.35      ],
#        ...,
#        [0.14925373, 0.56923077, 0.32743363, 0.12328767, 0.49      ],
#        [0.37313433, 0.26153846, 0.53097345, 0.61643836, 0.43      ],
#        [0.3880597 , 0.09230769, 0.26548673, 0.25342466, 0.33      ]],
#       shape=(1028, 5))

# %%
x_train_scaled=pd.DataFrame(data=x_train_scaled)

# %%
x_test_scaled=pd.DataFrame(data=x_test_scaled)

# %%
x_test_scaled
# Out:
#             0         1         2         3     4
# 0    0.343284  0.215385  0.256637  0.335616  0.26
# 1    0.089552  0.153846  0.283186  0.294521  0.00
# 2    0.164179  0.092308  0.318584  0.150685  0.38
# 3    0.059701  0.400000  0.300885  0.356164  0.22
# 4    0.328358  0.169231  0.292035  0.315068  0.23
# ..        ...       ...       ...       ...   ...
# 110  0.238806  0.169231  0.769912  0.150685  0.52
# 111  0.059701  0.338462  0.486726  0.171233  0.34
# 112  0.059701  0.169231  0.513274  0.109589  0.54
# 113  0.552239  0.153846  0.415929  0.191781  0.49
# 114  0.074627  0.430769  0.265487  0.198630  0.33
#
# [115 rows x 5 columns]

# %%
# train
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# prediction
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([[5.27976845],
#        [5.33137382],
#        [5.44570796],
#        [5.70538953],
#        [5.24875584],
#        [5.11482633],
#        [5.67031117],
#        [5.17367172],
#        [5.52984242],
#        [6.03911825],
#        [4.95383465],
#        [4.73155126],
#        [5.90843417],
#        [5.51857418],
#        [5.71736857],
#        [5.10721685],
#        [5.71151358],
#        [5.77548659],
#        [5.25465474],
#        [5.1037998 ],
#        [6.56707584],
#        [5.65336256],
#        [5.49482854],
#        [5.30362441],
#        [4.88436463],
#        [6.47633207],
#        [5.55154429],
#        [5.29474174],
#        [5.4443454 ],
#        [5.441626  ],
#        [5.31444167],
#        [5.4729872 ],
#        [5.00101346],
#        [6.25571548],
#        [5.21827471],
#        [6.42516184],
#        [6.50527396],
#        [5.76070342],
#        [5.7397516 ],
#        [5.26684074],
#        [6.23252548],
#        [6.90759683],
#        [5.60049524],
#        [5.34247715],
#        [5.06521832],
#        [5.34293177],
#        [6.05110943],
#        [5.29205522],
#        [5.47783134],
#        [6.0806747 ],
#        [5.28536878],
#        [6.33989729],
#        [5.68135095],
#        [5.94284717],
#        [5.74372921],
#        [5.45106668],
#        [5.90944921],
#        [6.18979278],
#        [6.17055137],
#        [5.49583028],
#        [5.42504336],
#        [5.62129252],
#        [6.0085457 ],
#        [5.46175946],
#        [5.4543148 ],
#        [5.14905578],
#        [5.17800794],
#        [6.11536449],
#        [5.27608885],
#        [5.54954551],
#        [6.04588483],
#        [6.38820159],
#        [5.26665971],
#        [5.74751854],
#        [5.55124877],
#        [6.18979278],
#        [5.67184137],
#        [5.6286951 ],
#        [5.12820363],
#        [5.18345675],
#        [6.74696394],
#        [6.47905073],
#        [5.99262701],
#        [6.0874826 ],
#        [5.89961319],
#        [6.16405067],
#        [5.77513566],
#        [5.3475969 ],
#        [5.31365679],
#        [6.07489941],
#        [6.04629614],
#        [5.98493461],
#        [6.07093544],
#        [6.36637934],
#        [6.03498661],
#        [4.81282557],
#        [5.09775714],
#        [5.30122281],
#        [6.02526307],
#        [5.68021513],
#        [6.37316382],
#        [5.72920883],
#        [6.01904184],
#        [6.47633207],
#        [6.08292787],
#        [5.46813645],
#        [4.84657313],
#        [5.85269226],
#        [5.77118152],
#        [6.38103499],
#        [5.79124782],
#        [6.03062378],
#        [5.78144844],
#        [5.45360579],
#        [6.06235685]])

# %%
# 
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.2554018359504292

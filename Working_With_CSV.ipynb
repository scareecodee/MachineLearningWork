# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv" #Important: Use RAW GitHub URL

df = pd.read_csv(url)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# sep parameter --> by default sep=',' so read_csv reads csv file by default .
#READING TSV FILE
df=pd.read_csv('Employee Dataset - TSV.txt',sep='\t')

# %%
df
# Out:
#    Employee Name  Age Last Working Day            Department      Education  \
# 0         Jitesh   41       31-12-9999              Training        Masters
# 1         Sanjit   49       31-12-9999                 Sales        Masters
# 2           John   37       31-12-9999                   R&D      Doctorate
# 3         Sandra   33       31-12-9999  Software Development  Undergraduate
# 4          Madhu   27       31-12-9999                   R&D        Masters
# 5         Robert   32       31-12-9999                   R&D        Masters
# 6          Megan   59       31-12-9999  Software Development        Masters
# 7           Matt   30       31-12-9999                   R&D      Doctorate
# 8           Will   38       01-03-2012                   R&D      Doctorate
# 9         George   36       31-12-9999  Software Development        Masters
# 10          Adam   35       31-12-9999  Software Development        Masters
# ...
